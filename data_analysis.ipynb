# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('merged_file.csv')

# %%
sales_by_segment = data.groupby(['LIFESTAGE', 'PREMIUM_CUSTOMER'])['TOT_SALES'].sum().reset_index().sort_values(by='TOT_SALES', ascending=False)
total_sales = data['TOT_SALES'].sum()
sales_by_segment['PRCT'] = (sales_by_segment['TOT_SALES'] / total_sales) * 100
sales_by_segment['PRCT_CUM'] = sales_by_segment['PRCT'].cumsum()
sales_by_segment
# Out:
#                  LIFESTAGE PREMIUM_CUSTOMER  TOT_SALES      PRCT    PRCT_CUM
# 19   YOUNG SINGLES/COUPLES       Mainstream  128464.50  9.091307    9.091307
# 6           OLDER FAMILIES           Budget  116190.95  8.222720   17.314027
# 13                RETIREES       Mainstream  115128.25  8.147514   25.461541
# 9    OLDER SINGLES/COUPLES           Budget  102636.80  7.263506   32.725048
# 11   OLDER SINGLES/COUPLES          Premium   99433.55  7.036815   39.761863
# 10   OLDER SINGLES/COUPLES       Mainstream   97503.10  6.900199   46.662062
# 15          YOUNG FAMILIES           Budget   97050.55  6.868173   53.530235
# 12                RETIREES           Budget   86867.60  6.147535   59.677770
# 14                RETIREES          Premium   74767.15  5.291198   64.968968
# 7           OLDER FAMILIES       Mainstream   71302.95  5.046040   70.015009
# 1   MIDAGE SINGLES/COUPLES       Mainstream   70742.05  5.006346   75.021355
# ...

# %%
# Out:
# LIFESTAGE            7
# PREMIUM_CUSTOMER     3
# LYLTY_CARD_NBR      21
# dtype: int64
