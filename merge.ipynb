# %%
# Merge dataframes
import pandas as pd

df1 = pd.read_csv('top_sales.csv')
df2 = pd.read_csv('QVI_purchase_behaviour.csv')

merged_df = pd.merge(df1, df2, on='LYLTY_CARD_NBR')

merged_df.to_csv('merged_file.csv', index=False)

# %%
df = pd.read_csv('merged_file.csv')
df
# Out:
#               DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0       2018-07-01         58           58072   53145        99
# 1       2018-07-01        199          199302  198907        23
# 2       2018-07-01         81           81292   81039       109
# 3       2018-07-01         32           32062   28370        31
# 4       2018-07-01        147          147113  146386        44
# ...            ...        ...             ...     ...       ...
# 167887  2019-06-30        186          186089  188493       109
# 167888  2019-06-30         91           91076   89519        40
# 167889  2019-06-30         84           84116   83704        77
# 167890  2019-06-30        199          199117  198068        77
# 167891  2019-06-30        220          220032  219497         4
#
#                                      PROD_NAME  PROD_QTY  TOT_SALES  \
# 0             Pringles Sthrn FriedChicken 134g         2        7.4
# 1                         Cheezels Cheese 330g         2       11.4
# 2                     Pringles Barbeque   134g         2        7.4
# 3       Infzns Crn Crnchers Tangy Gcamole 110g         2        7.6
# 4               Thins Chips Light&  Tangy 175g         2        6.6
# ...                                        ...       ...        ...
# 167887                Pringles Barbeque   134g         2        7.4
# 167888        Thins Chips Seasonedchicken 175g         2        6.6
# 167889   Doritos Corn Chips  Nacho Cheese 170g         2        8.8
# 167890   Doritos Corn Chips  Nacho Cheese 170g         2        8.8
# 167891        Dorito Corn Chp     Supreme 380g         2       13.0
#
#         PACK_SIZE      BRAND               LIFESTAGE PREMIUM_CUSTOMER
# 0             134   Pringles   OLDER SINGLES/COUPLES          Premium
# 1             330   Cheezels   OLDER SINGLES/COUPLES       Mainstream
# 2             134   Pringles                RETIREES       Mainstream
# 3             110  Infuzions          OLDER FAMILIES          Premium
# 4             175      Thins   YOUNG SINGLES/COUPLES           Budget
# ...           ...        ...                     ...              ...
# 167887        134   Pringles  MIDAGE SINGLES/COUPLES          Premium
# 167888        175      Thins   YOUNG SINGLES/COUPLES       Mainstream
# 167889        170    Doritos   YOUNG SINGLES/COUPLES           Budget
# 167890        170    Doritos  MIDAGE SINGLES/COUPLES       Mainstream
# 167891        380    Doritos                RETIREES           Budget
#
# [167892 rows x 12 columns]

# %%
# Check for missing matchs
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167892 entries, 0 to 167891
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   DATE              167892 non-null  object
#  1   STORE_NBR         167892 non-null  int64
#  2   LYLTY_CARD_NBR    167892 non-null  int64
#  3   TXN_ID            167892 non-null  int64
#  4   PROD_NBR          167892 non-null  int64
#  5   PROD_NAME         167892 non-null  object
#  6   PROD_QTY          167892 non-null  int64
#  7   TOT_SALES         167892 non-null  float64
#  8   PACK_SIZE         167892 non-null  int64
#  9   BRAND             167892 non-null  object
#  10  LIFESTAGE         167892 non-null  object
#  11  PREMIUM_CUSTOMER  167892 non-null  object
# dtypes: float64(1), int64(6), object(5)
# memory usage: 15.4+ MB
